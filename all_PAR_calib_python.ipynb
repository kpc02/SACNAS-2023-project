# %%
import pandas as pd
import numpy as np
import pycmap
import os.path
from datetime import datetime, timedelta
import pytz
import matplotlib.pyplot as plt
import math
import requests
from bs4 import BeautifulSoup
import re

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# %%
# calls api from cmap and uses my token to do that
api = pycmap.API(token = "d24b5240-ea3a-45bd-8174-fdb7830d805f")

# %%
## this is a way to call the seaflow metadata to python from google drive
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly']

# The ID and range of a sample spreadsheet.
SAMPLE_SPREADSHEET_ID = '1Tsi7OWIZWfCQJqLDpId2aG_i-8Cp-p63PYjjvDkOtH4'
SAMPLE_RANGE_NAME = 'metadata'
creds = None
# The file token.json stores the user's access and refresh tokens, and is
# created automatically when the authorization flow completes for the first
# time.
if os.path.exists('token.json'):
    creds = Credentials.from_authorized_user_file('token.json', SCOPES)
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file(
            'credentials.json', SCOPES)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('token.json', 'w') as token:
        token.write(creds.to_json())
try:
    service = build('sheets', 'v4', credentials=creds)

    # Call the Sheets API
    sheet = service.spreadsheets()
    result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                range=SAMPLE_RANGE_NAME).execute()
    values = result.get('values', [])

    if not values:
        print('No data found.')

except HttpError as err:
    print(err)

# %%
seaflow_meta=pd.DataFrame(values)
seaflow_meta.columns=seaflow_meta.iloc[0]
seaflow_meta1 = seaflow_meta.iloc[1:]
# this seaflow_meta

# %%
def read_sfl(x):
    df = pd.read_csv(x, sep = '\t')
    cruise_split = x.rsplit('/',1)[-1]
    #output will be a string
    cruise_short = cruise_split.replace('.sfl', '')
    cruise_list = cruise_short.split('_')
    if len(cruise_list) > 2:
        cruise = "_".join([cruise_list[0], cruise_list[1]])
    elif len(cruise_list) == 2:
        cruise = cruise_list[0]
    ship = seaflow_meta.loc[seaflow_meta['cruise'] ==  cruise, 'Ship'].values[0]
    print(cruise)
    df['cruise'] = cruise
    df['ship'] = ship
    return df

#### .values converts pd.series to list but we had to get string from the list which is the first one

# %%
sfl = read_sfl("https://raw.githubusercontent.com/seaflow-uw/seaflow-sfl/master/curated/DeepDOM_989.sfl")
# Out:
# DeepDOM

# %%
sfl
# Out:
#                    FILE                       DATE  FILE DURATION      LAT  \
# 0        2013_084/1.evt  2013-03-25T22:26:18+00:00            180 -35.2701
# 1        2013_084/2.evt  2013-03-25T22:29:19+00:00            180 -35.2751
# 2        2013_084/3.evt  2013-03-25T22:32:19+00:00            180 -35.2802
# 3        2013_084/4.evt  2013-03-25T22:35:19+00:00            180 -35.2857
# 4        2013_084/5.evt  2013-03-25T22:38:19+00:00            180 -35.2913
# ...                 ...                        ...            ...      ...
# 18438  2013_124/405.evt  2013-05-04T23:46:40+00:00            180   9.6966
# 18439  2013_124/406.evt  2013-05-04T23:49:41+00:00            180   9.6957
# 18440  2013_124/407.evt  2013-05-04T23:53:40+00:00            180   9.6953
# 18441  2013_124/408.evt  2013-05-04T23:56:40+00:00            180   9.6954
# 18442  2013_124/409.evt  2013-05-04T23:59:40+00:00            180   9.6956
#
#            LON  CONDUCTIVITY  SALINITY  OCEAN TEMP   PAR  BULK RED  \
# 0     -53.9193        4.2799   30.3408     20.6960  2.88  315.3193
# 1     -53.9089        4.2825   30.3495     20.7131  2.13  289.7130
# 2     -53.8979        4.2727   30.2842     20.6959  2.13  203.3337
# 3     -53.8871        4.2736   30.2921     20.6948  1.88  178.3893
# 4     -53.8761        4.2725   30.3122     20.6545  2.63  165.5252
# ...        ...           ...       ...         ...   ...       ...
# 18438 -55.2838        5.4849   33.5621     28.6630   NaN   67.7477
# 18439 -55.2837        5.4811   33.5396     28.6575   NaN  240.7669
# 18440 -55.2837        5.4827   33.5672     28.6339   NaN   69.2142
# 18441 -55.2837        5.4910   33.6119     28.6514   NaN   71.4513
# 18442 -55.2835        5.4932   33.6146     28.6691   NaN   74.1351
#
#        STREAM PRESSURE  EVENT RATE   cruise       ship
# 0                11.46        6554  DeepDOM  R/V Knorr
# 1                12.00       10374  DeepDOM  R/V Knorr
# 2                12.00       10099  DeepDOM  R/V Knorr
# 3                12.00        9959  DeepDOM  R/V Knorr
# 4                12.00        9796  DeepDOM  R/V Knorr
# ...                ...         ...      ...        ...
# 18438            12.00       31084  DeepDOM  R/V Knorr
# 18439            12.00       31028  DeepDOM  R/V Knorr
# 18440            18.41       28395  DeepDOM  R/V Knorr
# 18441            12.00       31348  DeepDOM  R/V Knorr
# 18442            12.00       31340  DeepDOM  R/V Knorr
#
# [18443 rows x 14 columns]

# %%
# this calls the rest of the sfl files from github sfl repo and uses beautiful soup to parse the text
github_url = 'https://github.com/seaflow-uw/seaflow-sfl/tree/master/curated'
results = requests.get(github_url)
soup = BeautifulSoup(results.text).get_text()

regex = '\.sfl'
match = pd.unique(re.findall('name.*?\.sfl', soup[560:]) )
# clean it up
filenames=[]
for i in match:
    filenames.append(i.split('"')[-1:][0])

# %%
filenames
# Out:
# ['DeepDOM_989.sfl',
#  'GP15_1_751.sfl',
#  'GP15_2_751.sfl',
#  'HOT-294_751.sfl',
#  'HOT297_751.sfl',
#  'HOT299_751.sfl',
#  'HOT300_751.sfl',
#  'HOT301_751.sfl',
#  'HOT302_751.sfl',
#  'HOT303_751.sfl',
#  'HOT304_751.sfl',
#  'HOT307_740.sfl',
#  'HOT308_740.sfl',
#  'HOT309_740.sfl',
#  'HOT310_740.sfl',
#  'HOT312_740.sfl',
#  'HOT313_740.sfl',
#  'HOT314_740.sfl',
#  'HOT315_740.sfl',
#  'HOT317_740.sfl',
#  'HOT318_740.sfl',
#  'HOT319_740.sfl',
#  'HOT321_740.sfl',
#  'HOT322_740.sfl',
#  'HOT323_740.sfl',
#  'HOT324_740.sfl',
#  'HOT325_740.sfl',
#  'HOT326_740.sfl',
#  'HOT328_740.sfl',
#  'HOT329_740.sfl',
#  'HOT330_740.sfl',
#  'HOT331_740.sfl',
#  'HOT332_740.sfl',
#  'HOT335_740.sfl',
#  'HOT336_740.sfl',
#  'HOT337_740.sfl',
#  'HOT338_740.sfl',
#  'KM1712_751.sfl',
#  'KM1713_751.sfl',
#  'KM1906_740.sfl',
#  'KM1906_towfish_751.sfl',
#  'KM1919_751.sfl',
#  'KM1920_751.sfl',
#  'KM1923_740_740.sfl',
#  'KM1923_751_751.sfl',
#  'KM2206_130_130.sfl',
#  'KM2206_740_740.sfl',
#  'KOK1805_751.sfl',
#  'KOK1806_751.sfl',
#  'KiloMoana_1_740.sfl',
#  'MBARI_1_989.sfl',
#  'MBARI_2_989.sfl',
#  'MBARI_3_989.sfl',
#  'MESO_SCOPE_751.sfl',
#  'MGL1704_751.sfl',
#  'SCOPE-PARAGONII_740.sfl',
#  'SCOPE-PARAGON_740.sfl',
#  'SCOPE_10_751.sfl',
#  'SCOPE_11_740.sfl',
#  'SCOPE_12_740.sfl',
#  'SCOPE_13_740.sfl',
#  'SCOPE_14_740.sfl',
#  'SCOPE_15_751.sfl',
#  'SCOPE_16_751.sfl',
#  'SCOPE_17_751.sfl',
#  'SCOPE_18_751.sfl',
#  'SCOPE_19_751.sfl',
#  'SCOPE_1_740.sfl',
#  'SCOPE_2_740.sfl',
#  'SCOPE_3_740.sfl',
#  'SCOPE_4_740.sfl',
#  'SCOPE_5_740.sfl',
#  'SCOPE_6_740.sfl',
#  'SCOPE_9_751.sfl',
#  'SCOPE_Falkor1_751.sfl',
#  'SCOPE_Falkor2_751.sfl',
#  'SR1917_751.sfl',
#  'TN396_130_130.sfl',
#  'TN396_740_740.sfl',
#  'TN397_130_130.sfl',
#  'TN397_740_740.sfl',
#  'TN398_740.sfl',
#  'TN412_130_130.sfl',
#  'TN413_130.sfl',
#  'TN414_130.sfl',
#  'Thompson_0_740.sfl',
#  'Thompson_10_740.sfl',
#  'Thompson_11_740.sfl',
#  'Thompson_12_740.sfl',
#  'Thompson_1_740.sfl',
#  'Thompson_2_740.sfl',
#  'Thompson_3_740.sfl',
#  'Thompson_4_740.sfl',
#  'Thompson_5_740.sfl',
#  'Thompson_6_740.sfl',
#  'Thompson_7_740.sfl',
#  'Thompson_8_740.sfl',
#  'Thompson_9_740.sfl',
#  'Tokyo_1_751.sfl',
#  'Tokyo_2_751.sfl',
#  'Tokyo_3_751.sfl',
#  'Tokyo_4_751.sfl']

# %%
# def list_cruises():
#     new_sfl = []
#     all_cruises = []
#     for i in filenames:
#         new_sfl.append(github_url + '/' + i)
#     for i in new_sfl:
#         read_sfl(i)
#     return list_cruises

# %%
# creates empty list so i can put entire github url in it so i can run read_sfl in it
all_cruises = []
raw_github = 'https://raw.githubusercontent.com/seaflow-uw/seaflow-sfl/master/curated'
for i in filenames:
    new_sfl = raw_github + '/' + i
    all_cruises.append(read_sfl(new_sfl))
# Out:
# DeepDOM
# GP15_1
# GP15_2
# HOT-294
# HOT297
# HOT299
# HOT300
# HOT301
# HOT302
# HOT303
# HOT304
# HOT307
# HOT308
# HOT309
# HOT310
# HOT312
# HOT313
# HOT314
# HOT315
# HOT317
# HOT318
# HOT319
# HOT321
# HOT322
# HOT323
# HOT324
# HOT325
# HOT326
# HOT328
# HOT329
# HOT330
# HOT331
# HOT332
# HOT335
# HOT336
# HOT337
# HOT338
# KM1712
# KM1713
# KM1906
# KM1906_towfish
# KM1919
# KM1920
# KM1923_740
# KM1923_751
# KM2206_130
# KM2206_740
# KOK1805
# KOK1806
# KiloMoana_1
# MBARI_1
# MBARI_2
# MBARI_3
# MESO_SCOPE
# MGL1704
# SCOPE-PARAGONII
# SCOPE-PARAGON
# SCOPE_10
# SCOPE_11
# SCOPE_12
# SCOPE_13
# SCOPE_14
# SCOPE_15
# SCOPE_16
# SCOPE_17
# SCOPE_18
# SCOPE_19
# SCOPE_1
# SCOPE_2
# SCOPE_3
# SCOPE_4
# SCOPE_5
# SCOPE_6
# SCOPE_9
# SCOPE_Falkor1
# SCOPE_Falkor2
# SR1917
# TN396_130
# TN396_740
# TN397_130
# TN397_740
# TN398
# TN412_130
# TN413
# TN414
# Thompson_0
# Thompson_10
# Thompson_11
# Thompson_12
# Thompson_1
# Thompson_2
# Thompson_3
# Thompson_4
# Thompson_5
# Thompson_6
# Thompson_7
# Thompson_8
# Thompson_9
# Tokyo_1
# Tokyo_2
# Tokyo_3
# Tokyo_4

# %%
all_sfl = pd.concat(all_cruises)
all_sfl
# Out:
#                   FILE                       DATE  FILE DURATION      LAT  \
# 0       2013_084/1.evt  2013-03-25T22:26:18+00:00        180.000 -35.2701
# 1       2013_084/2.evt  2013-03-25T22:29:19+00:00        180.000 -35.2751
# 2       2013_084/3.evt  2013-03-25T22:32:19+00:00        180.000 -35.2802
# 3       2013_084/4.evt  2013-03-25T22:35:19+00:00        180.000 -35.2857
# 4       2013_084/5.evt  2013-03-25T22:38:19+00:00        180.000 -35.2913
# ...                ...                        ...            ...      ...
# 3160  2012_037/418.evt  2012-02-06T20:52:52+00:00        179.987  33.6448
# 3161  2012_037/419.evt  2012-02-06T20:55:52+00:00        180.405  33.6407
# 3162  2012_037/420.evt  2012-02-06T20:58:53+00:00        180.182  33.6367
# 3163  2012_037/421.evt  2012-02-06T21:01:53+00:00        180.131  33.6327
# 3164  2012_037/422.evt  2012-02-06T21:04:53+00:00        180.000  33.6287
#
#            LON  CONDUCTIVITY  SALINITY  OCEAN TEMP   PAR  BULK RED  \
# 0     -53.9193       4.27990   30.3408     20.6960  2.88  315.3193
# 1     -53.9089       4.28250   30.3495     20.7131  2.13  289.7130
# 2     -53.8979       4.27270   30.2842     20.6959  2.13  203.3337
# 3     -53.8871       4.27360   30.2921     20.6948  1.88  178.3893
# 4     -53.8761       4.27250   30.3122     20.6545  2.63  165.5252
# ...        ...           ...       ...         ...   ...       ...
# 3160 -118.4801       4.09840   33.3094     14.7736   NaN   77.4531
# 3161 -118.4721       4.09931   33.3057     14.7814   NaN   71.7936
# 3162 -118.4639       4.10011   33.2993     14.7970   NaN   60.4821
# 3163 -118.4558       4.10251   33.3005     14.8224   NaN   67.4903
# 3164 -118.4476       4.10313   33.3064     14.8126   NaN   59.7295
#
#       STREAM PRESSURE  EVENT RATE   cruise       ship
# 0               11.46      6554.0  DeepDOM  R/V Knorr
# 1               12.00     10374.0  DeepDOM  R/V Knorr
# 2               12.00     10099.0  DeepDOM  R/V Knorr
# 3               12.00      9959.0  DeepDOM  R/V Knorr
# 4               12.00      9796.0  DeepDOM  R/V Knorr
# ...               ...         ...      ...        ...
# 3160             4.06         0.0  Tokyo_4  M/V Tokyo
# 3161             4.03         0.0  Tokyo_4  M/V Tokyo
# 3162             4.02         0.0  Tokyo_4  M/V Tokyo
# 3163             4.03         0.0  Tokyo_4  M/V Tokyo
# 3164             4.03         0.0  Tokyo_4  M/V Tokyo
#
# [402375 rows x 14 columns]

# %%
pd.to_datetime(all_sfl['DATE'])
# this converts all_sfl date column from object type to datetime in UTC

datetime_index = pd.DatetimeIndex(all_sfl.DATE.values).tz_convert('UTC')
df2 = all_sfl.set_index(datetime_index).reset_index()
df2.rename(columns={"index": "Date"}, inplace = True)
df2.drop(columns = ['DATE'], inplace = True)

# convert datetime64 to datetimeindex for groupby function to work
## i changed df because i was scared to mess up all_sfl df i was working with so I may have to change code to alter all_sfl df

# %%
sfl_hourly = df2.groupby([pd.Grouper(key = 'Date', freq = 'H'), 'cruise']).agg({'PAR': 'mean'}, numeric_only = True).reset_index()
# goal here is to group cruise and date column and . agg mean par to get hourly par data
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1791, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1790 try:
# -> 1791     result = self.grouper._cython_operation(
#    1792         "aggregate",
#    1793         values,
#    1794         how,
#    1795         axis=data.ndim - 1,
#    1796         min_count=min_count,
#    1797         **kwargs,
#    1798     )
#    1799 except NotImplementedError:
#    1800     # generally if we have numeric_only=False
#    1801     # and non-applicable functions
#    1802     # try to python agg
#    1803     # TODO: shouldn't min_count matter?
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/groupby/ops.py:1039, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#    1038 ngroups = self.ngroups
# -> 1039 return cy_op.cython_operation(
#    1040     values=values,
#    1041     axis=axis,
#    1042     min_count=min_count,
#    1043     comp_ids=ids,
#    1044     ngroups=ngroups,
#    1045     **kwargs,
#    1046 )
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/groupby/ops.py:708, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     700     return self._ea_wrap_cython_operation(
#     701         values,
#     702         min_count=min_count,
#    (...)
#     705         **kwargs,
#     706     )
# --> 708 return self._cython_op_ndim_compat(
#     709     values,
#     710     min_count=min_count,
#     711     ngroups=ngroups,
#     712     comp_ids=comp_ids,
#     713     mask=None,
#     714     **kwargs,
#     715 )
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/groupby/ops.py:512, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     511     result_mask = result_mask[None, :]
# --> 512 res = self._call_cython_op(
#     513     values2d,
#     514     min_count=min_count,
#     515     ngroups=ngroups,
#     516     comp_ids=comp_ids,
#     517     mask=mask,
#     518     result_mask=result_mask,
#     519     **kwargs,
#     520 )
#     521 if res.shape[0] == 1:
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/groupby/ops.py:571, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     570 out_shape = self._get_output_shape(ngroups, values)
# --> 571 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     572 values = self._get_cython_vals(values)
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/groupby/ops.py:192, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     190 elif "object" not in f.__signatures__:
#     191     # raise NotImplementedError here rather than TypeError later
# --> 192     raise NotImplementedError(
#     193         f"function is not implemented for this dtype: "
#     194         f"[how->{how},dtype->{dtype_str}]"
#     195     )
#     196 return f
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/nanops.py:1630, in _ensure_numeric(x)
#    1629 try:
# -> 1630     x = float(x)
#    1631 except (TypeError, ValueError):
#    1632     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: '1096.70001075.00001055.20001031.10001008.3000979.8100956.6500855.7900850.4000822.6700801.6600777.1500'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/nanops.py:1634, in _ensure_numeric(x)
#    1633 try:
# -> 1634     x = complex(x)
#    1635 except ValueError as err:
#    1636     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 sfl_hourly = df2.groupby([pd.Grouper(key = 'Date', freq = 'H'), 'cruise']).agg({'PAR': 'mean'}, numeric_only=True).reset_index()
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/groupby/generic.py:895, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     892 func = maybe_mangle_lambdas(func)
#     894 op = GroupByApply(self, func, args, kwargs)
# --> 895 result = op.agg()
#     896 if not is_dict_like(func) and result is not None:
#     897     return result
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/apply.py:172, in Apply.agg(self)
#     169     return self.apply_str()
#     171 if is_dict_like(arg):
# --> 172     return self.agg_dict_like()
#     173 elif is_list_like(arg):
#     174     # we require a list, but not a 'str'
#     175     return self.agg_list_like()
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/apply.py:504, in Apply.agg_dict_like(self)
#     501     results = {key: colg.agg(how) for key, how in arg.items()}
#     502 else:
#     503     # key used for column selection and output
# --> 504     results = {
#     505         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     506     }
#     508 # set the final keys
#     509 keys = list(arg.keys())
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/apply.py:505, in <dictcomp>(.0)
#     501     results = {key: colg.agg(how) for key, how in arg.items()}
#     502 else:
#     503     # key used for column selection and output
#     504     results = {
# --> 505         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     506     }
#     508 # set the final keys
#     509 keys = list(arg.keys())
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/groupby/generic.py:275, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     272     kwargs = {}
#     274 if isinstance(func, str):
# --> 275     return getattr(self, func)(*args, **kwargs)
#     277 elif isinstance(func, abc.Iterable):
#     278     # Catch instances of lists / tuples
#     279     # but not the class list / tuple itself.
#     280     func = maybe_mangle_lambdas(func)
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2183, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2181     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    2182 else:
# -> 2183     result = self._cython_agg_general(
#    2184         "mean",
#    2185         alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#    2186         numeric_only=numeric_only,
#    2187     )
#    2188     return result.__finalize__(self.obj, method="groupby")
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1810, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, ignore_failures, **kwargs)
#    1806     return result
#    1808 # TypeError -> we may have an exception in trying to aggregate
#    1809 #  continue and exclude the block
# -> 1810 new_mgr = data.grouped_reduce(array_func, ignore_failures=ignore_failures)
#    1812 if not is_ser and len(new_mgr) < orig_len:
#    1813     warn_dropping_nuisance_columns_deprecated(type(self), how, numeric_only)
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/internals/base.py:199, in SingleDataManager.grouped_reduce(self, func, ignore_failures)
#     193 """
#     194 ignore_failures : bool, default False
#     195     Not used; for compatibility with ArrayManager/BlockManager.
#     196 """
#     198 arr = self.array
# --> 199 res = func(arr)
#     200 index = default_index(len(res))
#     202 mgr = type(self).from_array(res, index)
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1804, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1791     result = self.grouper._cython_operation(
#    1792         "aggregate",
#    1793         values,
#    (...)
#    1797         **kwargs,
#    1798     )
#    1799 except NotImplementedError:
#    1800     # generally if we have numeric_only=False
#    1801     # and non-applicable functions
#    1802     # try to python agg
#    1803     # TODO: shouldn't min_count matter?
# -> 1804     result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1806 return result
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1745, in GroupBy._agg_py_fallback(self, values, ndim, alt)
#    1740     ser = df.iloc[:, 0]
#    1742 # We do not get here with UDFs, so we know that our dtype
#    1743 #  should always be preserved by the implemented aggregations
#    1744 # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1745 res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1747 if isinstance(values, Categorical):
#    1748     # Because we only get here with known dtype-preserving
#    1749     #  reductions, we cast back to Categorical.
#    1750     # TODO: if we ever get "rank" working, exclude it here.
#    1751     res_values = type(values)._from_sequence(res_values, dtype=values.dtype)
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/groupby/ops.py:1081, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#    1078     preserve_dtype = True
#    1080 else:
# -> 1081     result = self._aggregate_series_pure_python(obj, func)
#    1083 npvalues = lib.maybe_convert_objects(result, try_float=False)
#    1084 if preserve_dtype:
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/groupby/ops.py:1104, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1101 splitter = get_splitter(obj, ids, ngroups, axis=0)
#    1103 for i, group in enumerate(splitter):
# -> 1104     res = func(group)
#    1105     res = libreduction.extract_result(res)
#    1107     if not initialized:
#    1108         # We only do this validation on the first iteration
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2185, in GroupBy.mean.<locals>.<lambda>(x)
#    2181     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    2182 else:
#    2183     result = self._cython_agg_general(
#    2184         "mean",
# -> 2185         alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#    2186         numeric_only=numeric_only,
#    2187     )
#    2188     return result.__finalize__(self.obj, method="groupby")
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# > 11847     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/generic.py:11401, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11393 def mean(
#   11394     self,
#   11395     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11399     **kwargs,
#   11400 ) -> Series | float:
# > 11401     return self._stat_function(
#   11402         "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   11403     )
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/generic.py:11353, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   11343     warnings.warn(
#   11344         "Using the level keyword in DataFrame and Series aggregations is "
#   11345         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   11348         stacklevel=find_stack_level(),
#   11349     )
#   11350     return self._agg_by_level(
#   11351         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   11352     )
# > 11353 return self._reduce(
#   11354     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11355 )
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/series.py:4816, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4812     raise NotImplementedError(
#    4813         f"Series.{name} does not implement {kwd_name}."
#    4814     )
#    4815 with np.errstate(all="ignore"):
# -> 4816     return op(delegate, skipna=skipna, **kwds)
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
#      92     with np.errstate(invalid="ignore"):
# ---> 93         return f(*args, **kwargs)
#      94 except ValueError as e:
#      95     # we want to transform an object array
#      96     # ValueError message to the more typical TypeError
#      97     # e.g. this is normally a disallowed function on
#      98     # object arrays that contain strings
#      99     if is_object_dtype(args[0]):
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/nanops.py:418, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     415 if datetimelike and mask is None:
#     416     mask = isna(values)
# --> 418 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     420 if datetimelike:
#     421     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/nanops.py:706, in nanmean(values, axis, skipna, mask)
#     703     dtype_count = dtype
#     705 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 706 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     708 if axis is not None and getattr(the_sum, "ndim", False):
#     709     count = cast(np.ndarray, count)
#
# File ~/anaconda3/envs/par/lib/python3.11/site-packages/pandas/core/nanops.py:1637, in _ensure_numeric(x)
#    1634             x = complex(x)
#    1635         except ValueError as err:
#    1636             # e.g. "foo"
# -> 1637             raise TypeError(f"Could not convert {x} to numeric") from err
#    1638 return x
#
# TypeError: Could not convert 1096.70001075.00001055.20001031.10001008.3000979.8100956.6500855.7900850.4000822.6700801.6600777.1500 to numeric

# %%
def check_int(value):
    try:
        int(value)
        return np.NaN
    except ValueError:
        return value

# %%
x = sfl_hourly.Date
y = sfl_hourly.PAR
plt.plot(x, y)

# %%
df2.PAR = 10**-6 * df2.PAR * 24 * 60 * 60
# time to convert PAR units from microeinstein to einstein to match satellite date

# %%
lat_value = df2[df2.LAT.notnull()]
lon_value = df2[df2.LON.notnull()]
# here i've set indexed out the NaN values in lat and lon column before putting it into groupby function

sfl_daily = df2.groupby([pd.Grouper(key = 'Date', freq = 'D'), 'cruise', 'ship']).agg({
    'PAR': 'mean',
    'LAT': ['min', 'max'],
    'LON': ['min', 'max']}).reset_index()
# using group by to get the daily mean of par based on cruise, ship, etc. and removes any NaN values found. gets minimum and max of lat and lon based on daily scale

sfl_daily['sat_PAR'] = ''
# cretes empty column for sat_par that will be input by cmap data later

sfl_daily.columns = [' '.join(col).strip() for col in sfl_daily.columns.values]
# this flattens the multindex and joins the diff levels to create a min and max lat and lon instead of duplicate lat and lon columns

# %%
# cleaning up min_lat values
clean_sfl = sfl_daily.replace([np.inf, -np.inf], np.nan).dropna(subset=["LAT min", 
                                                            "LAT max",
                                                            'LON min',
                                                            'LON max'], how="any")

# %%
# colocalizing cmap data, sepcifically modis par data

for index,row in clean_sfl.iterrows():
    print(index, row)
    df = api.space_time(table='tblModis_PAR',
                   variable='PAR',
                   dt1= str(row['Date']),
                   dt2= str(row['Date']),
                   lat1= row['LAT min'],
                   lat2= row['LAT max'],
                   lon1= row['LON min'],
                   lon2= row['LON max'],
                   depth1=0,
                   depth2=10)
    try:
        clean_sfl.loc[index, 'sat_PAR'] = np.mean(df.PAR)
    except:
        clean_sfl.loc[index, 'sat_PAR'] = np.nan
# Out:
# 0 Date        2021-11-19 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    97.160599
# LAT min                      30.28238
# LAT max                       32.7066
# LON min                    -121.27732
# LON max                     -117.2363
# sat_PAR
# Name: 0, dtype: object
# 1 Date        2021-11-20 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    32.635551
# LAT min                     28.435675
# LAT max                       30.2781
# LON min                     -124.4034
# LON max                    -121.28435
# sat_PAR
# Name: 1, dtype: object
# 2 Date        2021-11-21 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    56.548363
# LAT min                     26.238867
# LAT max                     28.436408
# LON min                     -128.0429
# LON max                     -124.4031
# sat_PAR
# Name: 2, dtype: object
# 3 Date        2021-11-22 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    57.480665
# LAT min                     23.350209
# LAT max                     26.234092
# LON min                   -132.738909
# LON max                   -128.050667
# sat_PAR
# Name: 3, dtype: object
# 4 Date        2021-11-23 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    31.028783
# LAT min                     21.094933
# LAT max                     23.344383
# LON min                    -136.33165
# LON max                   -132.748458
# sat_PAR
# Name: 4, dtype: object
# 5 Date        2021-11-24 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                     40.28298
# LAT min                     19.637258
# LAT max                     21.090233
# LON min                   -138.617042
# LON max                   -136.338883
# sat_PAR
# Name: 5, dtype: object
# 6 Date        2021-11-25 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    34.521803
# LAT min                      19.47554
# LAT max                     19.676469
# LON min                   -138.615942
# LON max                   -138.490815
# sat_PAR
# Name: 6, dtype: object
# 7 Date        2021-11-26 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    45.642831
# LAT min                       16.6795
# LAT max                     19.475254
# LON min                    -140.34315
# LON max                   -138.573746
# sat_PAR
# Name: 7, dtype: object
# 8 Date        2021-11-27 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    66.466654
# LAT min                       12.9391
# LAT max                     16.671967
# LON min                     -140.0032
# LON max                   -139.997058
# sat_PAR
# Name: 8, dtype: object
# 9 Date        2021-11-28 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    46.330965
# LAT min                     10.695475
# LAT max                     12.931542
# LON min                    -140.00365
# LON max                   -139.993075
# sat_PAR
# Name: 9, dtype: object
# 10 Date        2021-11-29 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    51.347219
# LAT min                     10.644325
# LAT max                     10.730217
# LON min                   -140.111958
# LON max                   -139.608975
# sat_PAR
# Name: 10, dtype: object
# 11 Date        2021-11-30 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    65.166734
# LAT min                      7.332367
# LAT max                     10.652175
# LON min                   -140.128775
# LON max                     -139.9787
# sat_PAR
# Name: 11, dtype: object
# 12 Date        2021-12-01 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    67.536433
# LAT min                        4.7506
# LAT max                      7.325758
# LON min                   -140.008442
# LON max                      -139.988
# sat_PAR
# Name: 12, dtype: object
# 13 Date        2021-12-02 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    71.703384
# LAT min                       3.58343
# LAT max                        4.8642
# LON min                    -140.05645
# LON max                   -139.909158
# sat_PAR
# Name: 13, dtype: object
# 14 Date        2021-12-03 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    79.666679
# LAT min                      0.167064
# LAT max                      3.577667
# LON min                   -140.020425
# LON max                   -139.996817
# sat_PAR
# Name: 14, dtype: object
# 15 Date        2021-12-04 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    71.033779
# LAT min                     -0.001733
# LAT max                      0.268044
# LON min                   -140.001325
# LON max                     -139.8889
# sat_PAR
# Name: 15, dtype: object
# 16 Date        2021-12-05 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    70.071745
# LAT min                      -0.51672
# LAT max                      0.518575
# LON min                   -140.001683
# LON max                     -139.5897
# sat_PAR
# Name: 16, dtype: object
# 17 Date        2021-12-06 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    73.715059
# LAT min                          -2.5
# LAT max                     -0.523317
# LON min                   -140.036167
# LON max                   -139.948217
# sat_PAR
# Name: 17, dtype: object
# 18 Date        2021-12-07 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    70.872653
# LAT min                     -2.481583
# LAT max                       -0.5597
# LON min                     -141.4292
# LON max                     -139.9769
# sat_PAR
# Name: 18, dtype: object
# 19 Date        2021-12-08 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    66.191853
# LAT min                     -0.554175
# LAT max                      1.017465
# LON min                   -142.589197
# LON max                   -141.433275
# sat_PAR
# Name: 19, dtype: object
# 20 Date        2021-12-09 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    65.730574
# LAT min                      1.022783
# LAT max                      4.512233
# LON min                     -145.1727
# LON max                   -142.593525
# sat_PAR
# Name: 20, dtype: object
# 21 Date        2021-12-10 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    37.180761
# LAT min                      4.519625
# LAT max                       7.24385
# LON min                   -147.204625
# LON max                   -145.177967
# sat_PAR
# Name: 21, dtype: object
# 22 Date        2021-12-11 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    16.314538
# LAT min                       7.24745
# LAT max                      9.250058
# LON min                   -148.698108
# LON max                     -147.2073
# sat_PAR
# Name: 22, dtype: object
# 23 Date        2021-12-12 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                   152.045408
# LAT min                     11.919346
# LAT max                      12.48051
# LON min                    -151.12164
# LON max                   -150.685925
# sat_PAR
# Name: 23, dtype: object
# 24 Date        2021-12-13 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                    62.330895
# LAT min                     12.488915
# LAT max                     15.170767
# LON min                   -153.170478
# LON max                   -151.127946
# sat_PAR
# Name: 24, dtype: object
# 25 Date        2021-12-14 00:00:00+00:00
# cruise                      TN397_130
# ship            R/V Thomas G Thompson
# PAR mean                   128.512189
# LAT min                     18.180617
# LAT max                       19.2624
# LON min                   -156.347714
# LON max                   -155.508292
# sat_PAR
# Name: 25, dtype: object

# %%
# calculates the correction factor and makes column in clean_sfl

correction = (clean_sfl['sat_PAR'] / clean_sfl['PAR mean']).median()
clean_sfl['correction'] = correction

# %%
# figure plotting stuff out later

x = clean_sfl['Date']
y1 = clean_sfl['sat_PAR']
y2 = clean_sfl['PAR mean'] * correction


plt.scatter(x, y1, color='red', label='sat_PAR')
plt.scatter(x, y2, color='black', label='PAR')


plt.xlabel("Date")
plt.ylabel("Uncalib PAR")
plt.title("TN397_130") ### change this so that each plot made is specific to matching cruise .. idk how yet
plt.grid()

# %%
calib = clean_sfl.groupby(['cruise', 'ship']).agg({
    'Date' : 'mean',
    'correction' : 'mean'
}).round(3)

# %%
calib
# Out:
#                                                      Date  correction
# cruise    ship
# TN397_130 R/V Thomas G Thompson 2021-12-01 12:00:00+00:00       0.627
